# %% [markdown]
# # NEF summary
#
# The Neural Engineering Framework (NEF)
# is one set of theoretical methods that are used in
# Nengo for constructing neural models.
# The NEF is based on [Eliasmith & Anderson's (2003) book](
# https://mitpress.mit.edu/books/neural-engineering) from MIT Press.
# This notebook introduces the three main principles
# discussed in that book and implemented in Nengo.

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

import nengo
from nengo.dists import Uniform
from nengo.processes import WhiteSignal
from nengo.utils.ensemble import tuning_curves
from nengo.utils.ipython import hide_input
from nengo.utils.matplotlib import rasterplot


def aligned(n_neurons, radius=0.9):
    intercepts = np.linspace(-radius, radius, n_neurons)
    encoders = np.tile([[1], [-1]], (n_neurons // 2, 1))
    intercepts *= encoders[:, 0]
    return intercepts, encoders


hide_input()
# Out:
#         <a id="1403458752" href="javascript:toggle_input_1403458752()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1403458752;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1403458752 = document.getElementById("1403458752");
#                 var cell = link_1403458752;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1403458752;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1403458752 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1403458752 = cell.previousElementSibling;
#                 }
#                 input_1403458752.style.display = "none"; // hide
#
#                 toggle_input_1403458752 = function() {
#                     if (input_1403458752.style.display == "none") {
#                         input_1403458752.style.display = ""; // show
#                         link_1403458752.innerHTML = "Hide Input";
#                     } else {
#                         input_1403458752.style.display = "none"; // hide
#                         link_1403458752.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1403458752 = $("a[id='1403458752']");
#                 var cell_1403458752 = link_1403458752.parents("div.cell:first");
#                 if (cell_1403458752.length == 0) {
#                     cell_1403458752 = link_1403458752.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1403458752 = cell_1403458752.children("div.input");
#                 if (input_1403458752.length == 0) {
#                     input_1403458752 = cell_1403458752.prev("div.nbinput");
#                 }
#                 input_1403458752.hide();
#
#                 toggle_input_1403458752 = function() {
#                     if (input_1403458752.is(':hidden')) {
#                         input_1403458752.slideDown();
#                         link_1403458752[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1403458752.slideUp();
#                         link_1403458752[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 1: Representation
#
# ### Encoding
#
# Neural populations represent time-varying signals
# through their spiking responses.
# A signal is a vector of real numbers of arbitrary length.
# This example is a 1D signal going from -1 to 1 in 1 second.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1.0)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], lw=2)
plt.title("Input signal")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="348423858" href="javascript:toggle_input_348423858()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_348423858;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_348423858 = document.getElementById("348423858");
#                 var cell = link_348423858;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_348423858;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_348423858 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_348423858 = cell.previousElementSibling;
#                 }
#                 input_348423858.style.display = "none"; // hide
#
#                 toggle_input_348423858 = function() {
#                     if (input_348423858.style.display == "none") {
#                         input_348423858.style.display = ""; // show
#                         link_348423858.innerHTML = "Hide Input";
#                     } else {
#                         input_348423858.style.display = "none"; // hide
#                         link_348423858.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_348423858 = $("a[id='348423858']");
#                 var cell_348423858 = link_348423858.parents("div.cell:first");
#                 if (cell_348423858.length == 0) {
#                     cell_348423858 = link_348423858.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_348423858 = cell_348423858.children("div.input");
#                 if (input_348423858.length == 0) {
#                     input_348423858 = cell_348423858.prev("div.nbinput");
#                 }
#                 input_348423858.hide();
#
#                 toggle_input_348423858 = function() {
#                     if (input_348423858.is(':hidden')) {
#                         input_348423858.slideDown();
#                         link_348423858[0].innerHTML = "Hide Input";
#                     } else {
#                         input_348423858.slideUp();
#                         link_348423858[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# These signals drive neural populations
# based on each neuron's *tuning curve*
# (which is similar to the current-frequency curve,
# if you're familiar with that).
#
# The tuning curve describes how much
# a particular neuron will fire as a function of the input signal.

# %%
intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
with model:
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )

# %%
with nengo.Simulator(model) as sim:
    eval_points, activities = tuning_curves(A, sim)

plt.figure()
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")
hide_input()
# Out:
#         <a id="813389776" href="javascript:toggle_input_813389776()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_813389776;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_813389776 = document.getElementById("813389776");
#                 var cell = link_813389776;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_813389776;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_813389776 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_813389776 = cell.previousElementSibling;
#                 }
#                 input_813389776.style.display = "none"; // hide
#
#                 toggle_input_813389776 = function() {
#                     if (input_813389776.style.display == "none") {
#                         input_813389776.style.display = ""; // show
#                         link_813389776.innerHTML = "Hide Input";
#                     } else {
#                         input_813389776.style.display = "none"; // hide
#                         link_813389776.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_813389776 = $("a[id='813389776']");
#                 var cell_813389776 = link_813389776.parents("div.cell:first");
#                 if (cell_813389776.length == 0) {
#                     cell_813389776 = link_813389776.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_813389776 = cell_813389776.children("div.input");
#                 if (input_813389776.length == 0) {
#                     input_813389776 = cell_813389776.prev("div.nbinput");
#                 }
#                 input_813389776.hide();
#
#                 toggle_input_813389776 = function() {
#                     if (input_813389776.is(':hidden')) {
#                         input_813389776.slideDown();
#                         link_813389776[0].innerHTML = "Hide Input";
#                     } else {
#                         input_813389776.slideUp();
#                         link_813389776[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# We can drive these neurons with our input signal
# and observe their spiking activity over time.

# %%
with model:
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
ax = plt.subplot(1, 1, 1)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
ax.set_xlim(0, 1)
ax.set_ylabel("Neuron")
ax.set_xlabel("Time (s)")
hide_input()
# Out:
#         <a id="540079842" href="javascript:toggle_input_540079842()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_540079842;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_540079842 = document.getElementById("540079842");
#                 var cell = link_540079842;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_540079842;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_540079842 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_540079842 = cell.previousElementSibling;
#                 }
#                 input_540079842.style.display = "none"; // hide
#
#                 toggle_input_540079842 = function() {
#                     if (input_540079842.style.display == "none") {
#                         input_540079842.style.display = ""; // show
#                         link_540079842.innerHTML = "Hide Input";
#                     } else {
#                         input_540079842.style.display = "none"; // hide
#                         link_540079842.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_540079842 = $("a[id='540079842']");
#                 var cell_540079842 = link_540079842.parents("div.cell:first");
#                 if (cell_540079842.length == 0) {
#                     cell_540079842 = link_540079842.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_540079842 = cell_540079842.children("div.input");
#                 if (input_540079842.length == 0) {
#                     input_540079842 = cell_540079842.prev("div.nbinput");
#                 }
#                 input_540079842.hide();
#
#                 toggle_input_540079842 = function() {
#                     if (input_540079842.is(':hidden')) {
#                         input_540079842.slideDown();
#                         link_540079842[0].innerHTML = "Hide Input";
#                     } else {
#                         input_540079842.slideUp();
#                         link_540079842[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ### Decoding
#
# We can estimate the input signal
# originally encoded by decoding the pattern of spikes.
# To do this, we first filter the spike train
# with a temporal filter that accounts for
# postsynaptic current (PSC) activity.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    intercepts, encoders = aligned(8)  # Makes evenly spaced intercepts
    A = nengo.Ensemble(
        8,
        dimensions=1,
        intercepts=intercepts,
        max_rates=Uniform(80, 100),
        encoders=encoders,
    )
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

scale = 180
plt.figure()
for i in range(A.n_neurons):
    plt.plot(sim.trange(), sim.data[A_spikes][:, i] - i * scale)
plt.xlim(0, 1)
plt.ylim(scale * (-A.n_neurons + 1), scale)
plt.ylabel("Neuron")
plt.yticks(
    np.arange(scale / 1.8, (-A.n_neurons + 1) * scale, -scale), np.arange(A.n_neurons)
)
hide_input()
# Out:
#         <a id="1940605772" href="javascript:toggle_input_1940605772()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1940605772;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1940605772 = document.getElementById("1940605772");
#                 var cell = link_1940605772;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1940605772;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1940605772 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1940605772 = cell.previousElementSibling;
#                 }
#                 input_1940605772.style.display = "none"; // hide
#
#                 toggle_input_1940605772 = function() {
#                     if (input_1940605772.style.display == "none") {
#                         input_1940605772.style.display = ""; // show
#                         link_1940605772.innerHTML = "Hide Input";
#                     } else {
#                         input_1940605772.style.display = "none"; // hide
#                         link_1940605772.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1940605772 = $("a[id='1940605772']");
#                 var cell_1940605772 = link_1940605772.parents("div.cell:first");
#                 if (cell_1940605772.length == 0) {
#                     cell_1940605772 = link_1940605772.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1940605772 = cell_1940605772.children("div.input");
#                 if (input_1940605772.length == 0) {
#                     input_1940605772 = cell_1940605772.prev("div.nbinput");
#                 }
#                 input_1940605772.hide();
#
#                 toggle_input_1940605772 = function() {
#                     if (input_1940605772.is(':hidden')) {
#                         input_1940605772.slideDown();
#                         link_1940605772[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1940605772.slideUp();
#                         link_1940605772[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Then we mulitply those filtered spike trains
# with decoding weights and sum them together
# to give an estimate of the input based on the spikes.
#
# The decoding weights are determined
# by minimizing the squared difference
# between the decoded estimate and the actual input signal.

# %%
with model:
    A_probe = nengo.Probe(A, synapse=0.01)  # 10ms PSC filter

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure()
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded estimate")
plt.legend(loc="best")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="8930051" href="javascript:toggle_input_8930051()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_8930051;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_8930051 = document.getElementById("8930051");
#                 var cell = link_8930051;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_8930051;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_8930051 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_8930051 = cell.previousElementSibling;
#                 }
#                 input_8930051.style.display = "none"; // hide
#
#                 toggle_input_8930051 = function() {
#                     if (input_8930051.style.display == "none") {
#                         input_8930051.style.display = ""; // show
#                         link_8930051.innerHTML = "Hide Input";
#                     } else {
#                         input_8930051.style.display = "none"; // hide
#                         link_8930051.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_8930051 = $("a[id='8930051']");
#                 var cell_8930051 = link_8930051.parents("div.cell:first");
#                 if (cell_8930051.length == 0) {
#                     cell_8930051 = link_8930051.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_8930051 = cell_8930051.children("div.input");
#                 if (input_8930051.length == 0) {
#                     input_8930051 = cell_8930051.prev("div.nbinput");
#                 }
#                 input_8930051.hide();
#
#                 toggle_input_8930051 = function() {
#                     if (input_8930051.is(':hidden')) {
#                         input_8930051.slideDown();
#                         link_8930051[0].innerHTML = "Hide Input";
#                     } else {
#                         input_8930051.slideUp();
#                         link_8930051[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# The accuracy of the decoded estimate increases
# as the number of neurons increases.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: t * 2 - 1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(15, 3.5))

plt.subplot(1, 3, 1)
eval_points, activities = tuning_curves(A, sim)
plt.plot(eval_points, activities, lw=2)
plt.xlabel("Input signal")
plt.ylabel("Firing rate (Hz)")

ax = plt.subplot(1, 3, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")

plt.subplot(1, 3, 3)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)
hide_input()
# Out:
#         <a id="1257254939" href="javascript:toggle_input_1257254939()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1257254939;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1257254939 = document.getElementById("1257254939");
#                 var cell = link_1257254939;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1257254939;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1257254939 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1257254939 = cell.previousElementSibling;
#                 }
#                 input_1257254939.style.display = "none"; // hide
#
#                 toggle_input_1257254939 = function() {
#                     if (input_1257254939.style.display == "none") {
#                         input_1257254939.style.display = ""; // show
#                         link_1257254939.innerHTML = "Hide Input";
#                     } else {
#                         input_1257254939.style.display = "none"; // hide
#                         link_1257254939.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1257254939 = $("a[id='1257254939']");
#                 var cell_1257254939 = link_1257254939.parents("div.cell:first");
#                 if (cell_1257254939.length == 0) {
#                     cell_1257254939 = link_1257254939.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1257254939 = cell_1257254939.children("div.input");
#                 if (input_1257254939.length == 0) {
#                     input_1257254939 = cell_1257254939.prev("div.nbinput");
#                 }
#                 input_1257254939.hide();
#
#                 toggle_input_1257254939 = function() {
#                     if (input_1257254939.is(':hidden')) {
#                         input_1257254939.slideDown();
#                         link_1257254939[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1257254939.slideUp();
#                         link_1257254939[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Any smooth signal can be encoded and decoded.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[A_probe], label="Decoded esimate")
plt.legend(loc="best")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="80269210" href="javascript:toggle_input_80269210()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_80269210;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_80269210 = document.getElementById("80269210");
#                 var cell = link_80269210;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_80269210;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_80269210 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_80269210 = cell.previousElementSibling;
#                 }
#                 input_80269210.style.display = "none"; // hide
#
#                 toggle_input_80269210 = function() {
#                     if (input_80269210.style.display == "none") {
#                         input_80269210.style.display = ""; // show
#                         link_80269210.innerHTML = "Hide Input";
#                     } else {
#                         input_80269210.style.display = "none"; // hide
#                         link_80269210.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_80269210 = $("a[id='80269210']");
#                 var cell_80269210 = link_80269210.parents("div.cell:first");
#                 if (cell_80269210.length == 0) {
#                     cell_80269210 = link_80269210.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_80269210 = cell_80269210.children("div.input");
#                 if (input_80269210.length == 0) {
#                     input_80269210 = cell_80269210.prev("div.nbinput");
#                 }
#                 input_80269210.hide();
#
#                 toggle_input_80269210 = function() {
#                     if (input_80269210.is(':hidden')) {
#                         input_80269210.slideDown();
#                         link_80269210[0].innerHTML = "Hide Input";
#                     } else {
#                         input_80269210.slideUp();
#                         link_80269210[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 2: Transformation
#
# Encoding and decoding allow us to encode signals over time,
# and decode transformations of those signals.
#
# In fact, we can decode arbitrary transformations of the input signal,
# not just the signal itself (as in the previous example).
#
# Let's decode the square of our white noise input.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(WhiteSignal(1, high=5), size_out=1)
    input_probe = nengo.Probe(input)
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    Asquare = nengo.Node(size_in=1)
    nengo.Connection(input, A)
    nengo.Connection(A, Asquare, function=np.square)
    A_spikes = nengo.Probe(A.neurons)
    Asquare_probe = nengo.Probe(Asquare, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(1)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[input_probe], label="Input signal")
plt.plot(sim.trange(), sim.data[Asquare_probe], label="Decoded esimate")
plt.plot(sim.trange(), np.square(sim.data[input_probe]), label="Input signal squared")
plt.legend(loc="best", fontsize="medium")
plt.xlabel("Time (s)")
plt.xlim(0, 1)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes])
plt.xlim(0, 1)
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="2089268695" href="javascript:toggle_input_2089268695()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_2089268695;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_2089268695 = document.getElementById("2089268695");
#                 var cell = link_2089268695;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_2089268695;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_2089268695 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_2089268695 = cell.previousElementSibling;
#                 }
#                 input_2089268695.style.display = "none"; // hide
#
#                 toggle_input_2089268695 = function() {
#                     if (input_2089268695.style.display == "none") {
#                         input_2089268695.style.display = ""; // show
#                         link_2089268695.innerHTML = "Hide Input";
#                     } else {
#                         input_2089268695.style.display = "none"; // hide
#                         link_2089268695.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_2089268695 = $("a[id='2089268695']");
#                 var cell_2089268695 = link_2089268695.parents("div.cell:first");
#                 if (cell_2089268695.length == 0) {
#                     cell_2089268695 = link_2089268695.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_2089268695 = cell_2089268695.children("div.input");
#                 if (input_2089268695.length == 0) {
#                     input_2089268695 = cell_2089268695.prev("div.nbinput");
#                 }
#                 input_2089268695.hide();
#
#                 toggle_input_2089268695 = function() {
#                     if (input_2089268695.is(':hidden')) {
#                         input_2089268695.slideDown();
#                         link_2089268695[0].innerHTML = "Hide Input";
#                     } else {
#                         input_2089268695.slideUp();
#                         link_2089268695[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Notice that the spike trains are exactly the same.
# The only difference is how we're interpreting those spikes.
# We told Nengo to compute a new set of decoders
# that estimate the function $x^2$.
#
# In general, the transformation principle
# determines how we can decode spike trains
# to compute linear and nonlinear transformations of signals
# encoded in a population of neurons.
# We can then project those transformed signals
# into another population, and repeat the process.
# Essentially, this provides a means of
# computing the neural connection weights
# to compute an arbitrary function between populations.
#
# Suppose we are representing a sine wave.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: np.sin(np.pi * t))
    A = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(input, A)
    A_spikes = nengo.Probe(A.neurons)
    A_probe = nengo.Probe(A, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(1, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1339936006" href="javascript:toggle_input_1339936006()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1339936006;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1339936006 = document.getElementById("1339936006");
#                 var cell = link_1339936006;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1339936006;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1339936006 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1339936006 = cell.previousElementSibling;
#                 }
#                 input_1339936006.style.display = "none"; // hide
#
#                 toggle_input_1339936006 = function() {
#                     if (input_1339936006.style.display == "none") {
#                         input_1339936006.style.display = ""; // show
#                         link_1339936006.innerHTML = "Hide Input";
#                     } else {
#                         input_1339936006.style.display = "none"; // hide
#                         link_1339936006.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1339936006 = $("a[id='1339936006']");
#                 var cell_1339936006 = link_1339936006.parents("div.cell:first");
#                 if (cell_1339936006.length == 0) {
#                     cell_1339936006 = link_1339936006.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1339936006 = cell_1339936006.children("div.input");
#                 if (input_1339936006.length == 0) {
#                     input_1339936006 = cell_1339936006.prev("div.nbinput");
#                 }
#                 input_1339936006.hide();
#
#                 toggle_input_1339936006 = function() {
#                     if (input_1339936006.is(':hidden')) {
#                         input_1339936006.slideDown();
#                         link_1339936006[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1339936006.slideUp();
#                         link_1339936006[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Linear transformations of that signal
# involve solving for the usual decoders,
# and scaling those decoding weights.
# Let us flip this sine wave upside down
# as it is transmitted between two populations
# (i.e. population A and population -A).

# %%
with model:
    minusA = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(A, minusA, function=lambda x: -x)
    minusA_spikes = nengo.Probe(minusA.neurons)
    minusA_probe = nengo.Probe(minusA, synapse=0.01)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 5))
plt.subplot(2, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(2, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.title("-A")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(2, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(2, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="372342333" href="javascript:toggle_input_372342333()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_372342333;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_372342333 = document.getElementById("372342333");
#                 var cell = link_372342333;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_372342333;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_372342333 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_372342333 = cell.previousElementSibling;
#                 }
#                 input_372342333.style.display = "none"; // hide
#
#                 toggle_input_372342333 = function() {
#                     if (input_372342333.style.display == "none") {
#                         input_372342333.style.display = ""; // show
#                         link_372342333.innerHTML = "Hide Input";
#                     } else {
#                         input_372342333.style.display = "none"; // hide
#                         link_372342333.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_372342333 = $("a[id='372342333']");
#                 var cell_372342333 = link_372342333.parents("div.cell:first");
#                 if (cell_372342333.length == 0) {
#                     cell_372342333 = link_372342333.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_372342333 = cell_372342333.children("div.input");
#                 if (input_372342333.length == 0) {
#                     input_372342333 = cell_372342333.prev("div.nbinput");
#                 }
#                 input_372342333.hide();
#
#                 toggle_input_372342333 = function() {
#                     if (input_372342333.is(':hidden')) {
#                         input_372342333.slideDown();
#                         link_372342333[0].innerHTML = "Hide Input";
#                     } else {
#                         input_372342333.slideUp();
#                         link_372342333[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# Nonlinear transformations involve
# solving for a new set of decoding weights.
# Let us add a third population connected
# to the second one and use it to compute $(-A)^2$.

# %%
with model:
    A_squared = nengo.Ensemble(30, dimensions=1, max_rates=Uniform(80, 100))
    nengo.Connection(minusA, A_squared, function=lambda x: x ** 2)
    A_squared_spikes = nengo.Probe(A_squared.neurons)
    A_squared_probe = nengo.Probe(A_squared, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(2)

plt.figure(figsize=(10, 6.5))
plt.subplot(3, 2, 1)
plt.plot(sim.trange(), sim.data[A_probe])
plt.axhline(0, color="k")
plt.title("A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 3)
plt.plot(sim.trange(), sim.data[minusA_probe])
plt.axhline(0, color="k")
plt.title("-A")
plt.xticks(())
plt.xlim(0, 2)

plt.subplot(3, 2, 5)
plt.plot(sim.trange(), sim.data[A_squared_probe])
plt.axhline(0, color="k")
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.xlim(0, 2)

ax = plt.subplot(3, 2, 2)
rasterplot(sim.trange(), sim.data[A_spikes], ax)
plt.xlim(0, 2)
plt.title("A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 4)
rasterplot(sim.trange(), sim.data[minusA_spikes], ax)
plt.xlim(0, 2)
plt.title("-A")
plt.xticks(())
plt.ylabel("Neuron")

ax = plt.subplot(3, 2, 6)
rasterplot(sim.trange(), sim.data[A_squared_spikes], ax)
plt.xlim(0, 2)
plt.title("(-A)^2")
plt.xlabel("Time (s)")
plt.ylabel("Neuron")
hide_input()
# Out:
#         <a id="1611402060" href="javascript:toggle_input_1611402060()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_1611402060;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_1611402060 = document.getElementById("1611402060");
#                 var cell = link_1611402060;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_1611402060;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_1611402060 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_1611402060 = cell.previousElementSibling;
#                 }
#                 input_1611402060.style.display = "none"; // hide
#
#                 toggle_input_1611402060 = function() {
#                     if (input_1611402060.style.display == "none") {
#                         input_1611402060.style.display = ""; // show
#                         link_1611402060.innerHTML = "Hide Input";
#                     } else {
#                         input_1611402060.style.display = "none"; // hide
#                         link_1611402060.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_1611402060 = $("a[id='1611402060']");
#                 var cell_1611402060 = link_1611402060.parents("div.cell:first");
#                 if (cell_1611402060.length == 0) {
#                     cell_1611402060 = link_1611402060.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_1611402060 = cell_1611402060.children("div.input");
#                 if (input_1611402060.length == 0) {
#                     input_1611402060 = cell_1611402060.prev("div.nbinput");
#                 }
#                 input_1611402060.hide();
#
#                 toggle_input_1611402060 = function() {
#                     if (input_1611402060.is(':hidden')) {
#                         input_1611402060.slideDown();
#                         link_1611402060[0].innerHTML = "Hide Input";
#                     } else {
#                         input_1611402060.slideUp();
#                         link_1611402060[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>

# %% [markdown]
# ## Principle 3: Dynamics
#
# So far, we have been considering the values
# represented by ensembles as generic "signals."
# However, if we think of them instead
# as state variables in a dynamical system,
# then we can apply the methods of control theory
# or dynamic systems theory to brain models.
# Nengo automatically translates from standard dynamical systems descriptions
# to descriptions consistent with neural dynamics.
#
# In order to get interesting dynamics,
# we can connect populations recurrently (i.e., to themselves).
#
# Below is a simple harmonic oscillator
# implemented using this third principle.
# It needs is a bit of input to get it started.

# %%
model = nengo.Network(label="NEF summary")
with model:
    input = nengo.Node(lambda t: [1, 0] if t < 0.1 else [0, 0])
    oscillator = nengo.Ensemble(200, dimensions=2)
    nengo.Connection(input, oscillator)
    nengo.Connection(oscillator, oscillator, transform=[[1, 1], [-1, 1]], synapse=0.1)
    oscillator_probe = nengo.Probe(oscillator, synapse=0.02)

# %%
with nengo.Simulator(model) as sim:
    sim.run(3)

plt.figure(figsize=(10, 3.5))
plt.subplot(1, 2, 1)
plt.plot(sim.trange(), sim.data[oscillator_probe])
plt.ylim(-1.2, 1.2)
plt.xlabel("Time (s)")

plt.subplot(1, 2, 2)
plt.plot(sim.data[oscillator_probe][:, 0], sim.data[oscillator_probe][:, 1])
plt.grid()
plt.axis([-1.2, 1.2, -1.2, 1.2])
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
hide_input()
# Out:
#         <a id="691442668" href="javascript:toggle_input_691442668()"
#           >Show Input</a>
#
#         <script type="text/javascript">
#         var toggle_input_691442668;
#         (function() {
#             if (typeof jQuery == 'undefined') {
#                 // no jQuery
#                 var link_691442668 = document.getElementById("691442668");
#                 var cell = link_691442668;
#                 while (cell.className.split(' ')[0] != "cell"
#                        && cell.className.split(' ')[0] != "nboutput") {
#                     cell = cell.parentNode;
#                 }
#                 var input_691442668;
#                 if (cell.className.split(' ')[0] == "cell") {
#                     for (var i = 0; i < cell.children.length; i++) {
#                         if (cell.children[i].className.split(' ')[0]
#                             == "input") {
#                             input_691442668 = cell.children[i];
#                         }
#                     }
#                 } else {
#                     input_691442668 = cell.previousElementSibling;
#                 }
#                 input_691442668.style.display = "none"; // hide
#
#                 toggle_input_691442668 = function() {
#                     if (input_691442668.style.display == "none") {
#                         input_691442668.style.display = ""; // show
#                         link_691442668.innerHTML = "Hide Input";
#                     } else {
#                         input_691442668.style.display = "none"; // hide
#                         link_691442668.innerHTML = "Show Input";
#                     }
#                 }
#
#             } else {
#                 // jQuery
#                 var link_691442668 = $("a[id='691442668']");
#                 var cell_691442668 = link_691442668.parents("div.cell:first");
#                 if (cell_691442668.length == 0) {
#                     cell_691442668 = link_691442668.parents(
#                         "div.nboutput:first");
#                 }
#                 var input_691442668 = cell_691442668.children("div.input");
#                 if (input_691442668.length == 0) {
#                     input_691442668 = cell_691442668.prev("div.nbinput");
#                 }
#                 input_691442668.hide();
#
#                 toggle_input_691442668 = function() {
#                     if (input_691442668.is(':hidden')) {
#                         input_691442668.slideDown();
#                         link_691442668[0].innerHTML = "Hide Input";
#                     } else {
#                         input_691442668.slideUp();
#                         link_691442668[0].innerHTML = "Show Input";
#                     }
#                 }
#             }
#         }());
#         </script>
